# %% [markdown]
# ## Zulip chat data
# * [Zulip](https://zulipchat.com/) is an open source chat application that is used by many open source projects.
#
# https://github.com/onefact/datathinking.org-codespace/blob/main/notebooks/university-of-tartu/230420-zulip-chat-duckdb-loading.ipynb is an example of how to load Zulip chat data.
#
# ## TODO
# - [x] try running this example notebook
# - [ ] try running this example notebook with a different Zulip chat data set updated to today's date
#   - [ ] try following instructions here to download latest zulip data - https://github.com/onefact/datathinking.org-codespace/blob/main/notebooks/university-of-tartu/230316-embeddings-text-data-like-chat-logs-and-networks.ipynb
#   - [ ] maybe do most of the steps here and see if we can see the latest messages?
#   - [x] Follow https://zulip.com/help/export-your-organization
#   - [ ] rerun this notebook to see if we could update the data

# %%
# smallest possible test case for SQL query using jupyter notebook cell magic commands
import duckdb
import pandas as pd

# Import jupysql Jupyter extension to create SQL cells
# %load_ext sql

# Set configrations on jupysql to directly output data to Pandas and to simplify the output that is printed to the notebook.
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# Connect jupysql to DuckDB using a SQLAlchemy-style connection string. Either connect to an in memory DuckDB, or a file backed db.
# %sql duckdb:///:memory:

# %%
import os
zulip_path = os.getcwd() + "/messages-000001.json"
print(zulip_path)
# Out:
# /workspaces/DataThinkingUT/messages-000001.json

# %%
# %%sql
# SELECT UNNEST(l) FROM read_json_auto('./messages-000001.json',
#                maximum_object_size=99999999) tbl(l);
# Out:
#                                              unnest(l)
# 0    {'id': 299488052, 'sender': 100007, 'recipient...
# 1    {'id': 299488053, 'sender': 100007, 'recipient...
# 2    {'id': 299488054, 'sender': 100007, 'recipient...
# 3    {'id': 327255223, 'sender': 544719, 'recipient...
# 4    {'id': 327934641, 'sender': 588609, 'recipient...
# ..                                                 ...
# 552  {'id': 368040562, 'sender': 590536, 'recipient...
# 553  {'id': 368051747, 'sender': 587794, 'recipient...
# 554  {'id': 368053528, 'sender': 590536, 'recipient...
# 555  {'id': 368055562, 'sender': 622748, 'recipient...
# 556  {'id': 368056816, 'sender': 622751, 'recipient...
#
# [557 rows x 1 columns]

# %%
# %%sql
# COPY (SELECT UNNEST(zerver_message) AS zerver_message
# FROM read_json_auto("{{zulip_path}}",
#                     maximum_object_size=99999999)) TO './zerver_message.json';
# Out:
#    Count
# 0    557

# %%
# %%sql
# COPY (SELECT UNNEST(zerver_usermessage) AS zerver_usermessage
# FROM read_json_auto("{{zulip_path}}",
#                     maximum_object_size=99999999)) TO './zerver_usermessage.json';
# Out:
#    Count
# 0  53386

# %%
# %%sql
# COPY (SELECT UNNEST(zerver_usermessage) AS zerver_usermessage
# FROM read_json_auto("{{zulip_path}}",
#                     maximum_object_size=99999999)) TO './zerver_usermessage.parquet' (FORMAT PARQUET);
# Out:
#    Count
# 0  53386

# %%
# %%sql
# SELECT *
# FROM './zerver_usermessage.parquet'
# Out:
#                                       zerver_usermessage
# 0      {'id': 8257034355, 'user_profile': 544719, 'me...
# 1      {'id': 8257034356, 'user_profile': 544719, 'me...
# 2      {'id': 8257034357, 'user_profile': 544719, 'me...
# 3      {'id': 9332100997, 'user_profile': 587794, 'me...
# 4      {'id': 9332100998, 'user_profile': 544719, 'me...
# ...                                                  ...
# 53381  {'id': 10548357093, 'user_profile': 590323, 'm...
# 53382  {'id': 10548357094, 'user_profile': 622452, 'm...
# 53383  {'id': 10548357095, 'user_profile': 623094, 'm...
# 53384  {'id': 10548357096, 'user_profile': 624250, 'm...
# 53385  {'id': 10548357097, 'user_profile': 622718, 'm...
#
# [53386 rows x 1 columns]

# %%
# %%sql
# SELECT zerver_usermessage.id, zerver_usermessage.user_profile, zerver_usermessage.message, zerver_usermessage.flags_mask
# FROM './zerver_usermessage.parquet'
# Out:
#                 id  user_profile    message  flags_mask
# 0       8257034355        544719  299488052           1
# 1       8257034356        544719  299488053           1
# 2       8257034357        544719  299488054           1
# 3       9332100997        587794  327255223           1
# 4       9332100998        544719  327255223           1
# ...            ...           ...        ...         ...
# 53381  10548357093        590323  368056816           0
# 53382  10548357094        622452  368056816           0
# 53383  10548357095        623094  368056816           0
# 53384  10548357096        624250  368056816           0
# 53385  10548357097        622718  368056816           0
#
# [53386 rows x 4 columns]

# %%
# %%sql
# SELECT zerver_usermessage.id::UBIGINT as id,
#         zerver_usermessage.user_profile::UBIGINT as user_profile,
#         zerver_usermessage.message::UBIGINT as message,
#         zerver_usermessage.flags_mask::BOOLEAN as flags_mask
# FROM './zerver_usermessage.json'
# Out:
#                 id  user_profile    message  flags_mask
# 0       8257034355        544719  299488052        True
# 1       8257034356        544719  299488053        True
# 2       8257034357        544719  299488054        True
# 3       9332100997        587794  327255223        True
# 4       9332100998        544719  327255223        True
# ...            ...           ...        ...         ...
# 53381  10548357093        590323  368056816       False
# 53382  10548357094        622452  368056816       False
# 53383  10548357095        623094  368056816       False
# 53384  10548357096        624250  368056816       False
# 53385  10548357097        622718  368056816       False
#
# [53386 rows x 4 columns]

# %%
# %%sql
# SELECT zerver_usermessage.id::UBIGINT as id,
#         zerver_usermessage.user_profile::UBIGINT as user_profile,
#         zerver_usermessage.message::UBIGINT as message,
#         zerver_usermessage.flags_mask::BOOLEAN as flags_mask
# FROM './zerver_usermessage.json'
# Out:
#                 id  user_profile    message  flags_mask
# 0       8257034355        544719  299488052        True
# 1       8257034356        544719  299488053        True
# 2       8257034357        544719  299488054        True
# 3       9332100997        587794  327255223        True
# 4       9332100998        544719  327255223        True
# ...            ...           ...        ...         ...
# 53381  10548357093        590323  368056816       False
# 53382  10548357094        622452  368056816       False
# 53383  10548357095        623094  368056816       False
# 53384  10548357096        624250  368056816       False
# 53385  10548357097        622718  368056816       False
#
# [53386 rows x 4 columns]

# %%
# %%sql
# SELECT  zerver_message.id::UBIGINT as id,
#         zerver_message.sender::UBIGINT as sender,
#         zerver_message.recipient::BIGINT as recipient,
#         zerver_message.realm::UBIGINT as realm,
#         zerver_message.subject::VARCHAR as subject,
#         zerver_message.content::VARCHAR as content,
#         zerver_message.rendered_content::VARCHAR as rendered_content,
#         zerver_message.rendered_content_version::UBIGINT as rendered_content_version,
#         zerver_message.date_sent::VARCHAR as date_sent,
#         zerver_message.sending_client::BIGINT as sending_client,
#         zerver_message.last_edit_time::VARCHAR as last_edit_time,
#         zerver_message.edit_history::VARCHAR as edit_history,
#         zerver_message.has_attachment::BOOLEAN as has_attachment,
#         zerver_message.has_image::BOOLEAN as has_image,
#         zerver_message.has_link::BOOLEAN as has_link,
#         zerver_message.search_tsvector::VARCHAR as search_tsvector
# FROM './zerver_message.json'
#
# 	id
# Out:
#             id  sender  recipient  realm              subject  \
# 0    299488052  100007     924073  47304  topic demonstration
# 1    299488053  100007     924073  47304  topic demonstration
# 2    299488054  100007     924073  47304     swimming turtles
# 3    327255223  544719     924073  47304               intros
# 4    327934641  588609     924073  47304               intros
# ..         ...     ...        ...    ...                  ...
# 552  368040562  590536     924073  47304                 main
# 553  368051747  587794     924073  47304        Final Project
# 554  368053528  590536     924073  47304    Homework critique
# 555  368055562  622748     924073  47304   experience reports
# 556  368056816  622751     924073  47304   experience reports
#
#                                                content  \
# 0    This is a message on stream #**general** with ...
# 1    Topics are a lightweight tool to keep conversa...
# 2    This is a message on stream #**general** with ...
# 3    Hi! I am Jaan. I am teaching this course and t...
# 4    Hello Jaan,\nI am Nesma, a Ph.D. student at th...
# ..                                                 ...
# 552  My HW2:\n[Moonsund_Regatta_in_Estonia.png](/us...
# 553  My final project was a rushed job about:\n\n*I...
# 554  My critique of my own HW:\nhttps://github.com/...
# 555  My experience report: I had trouble setting up...
# 556  My experience report: Engaging with these new ...
#
#                                       rendered_content  \
# 0    <p>This is a message on stream <a class="strea...
# 1    <p>Topics are a lightweight tool to keep conve...
# 2    <p>This is a message on stream <a class="strea...
# 3    <p>Hi! I am Jaan. I am teaching this course an...
# 4    <p>Hello Jaan,<br>\nI am Nesma, a Ph.D. studen...
# ..                                                 ...
# 552  <p>My HW2:<br>\n<a href="/user_uploads/47304/x...
# 553  <p>My final project was a rushed job about:</p...
# 554  <p>My critique of my own HW:<br>\n<a href="htt...
# 555  <p>My experience report: I had trouble setting...
# 556  <p>My experience report: Engaging with these n...
#
#      rendered_content_version          date_sent  sending_client  \
# 0                           1  1663549367.691131            1002
# 1                           1  1663549367.706309            1002
# 2                           1  1663549367.719102            1002
# 3                           1  1676123703.264337            1000
# 4                           1  1676443984.123736            1163
# ..                        ...                ...             ...
# 552                         1  1687291025.133785            1000
# 553                         1  1687294428.516468            1000
# 554                         1  1687294959.328329            1000
# 555                         1  1687295705.690825            1000
# 556                         1  1687296138.839638            1000
#
#         last_edit_time                                       edit_history  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# ..                 ...                                                ...
# 552                NaN                                                NaN
# 553  1687294468.508179  [{"user_id":587794,"timestamp":1687294468,"pre...
# 554                NaN                                                NaN
# 555                NaN                                                NaN
# 556  1687296201.499384  [{"user_id":622751,"timestamp":1687296201,"pre...
#
#      has_attachment  has_image  has_link  \
# 0             False      False      True
# 1             False      False      True
# 2             False       True      True
# 3             False      False     False
# 4             False      False     False
# ..              ...        ...       ...
# 552            True       True      True
# 553           False      False      True
# 554           False      False      True
# 555           False      False     False
# 556           False      False     False
#
#                                        search_tsvector
# 0    'demonstrate':2,14 'demonstration':2,14 'gener...
# 1    'conversation':10 'demonstrate':2 'demonstrati...
# 2    'general':9 'message':6,28 'new':17 'ply':24 '...
# 3    'agency':32 'artificial':59 'behavior':44 'clo...
# 4    'acquire':45 'additional':70 'analysis':58 'ap...
# ..                                                 ...
# 552  '/onefact/datathinking.org/issues/110':8 '/one...
# 553  '/ikr503/blog.datathinking.org/blob/indrekblog...
# 554  '/onefact/datathinking.org/issues/163#issuecom...
# 555  '2':106 '3':37 'assumption':118 'beliefs':120 ...
# 556  '-1':84 '1':83 'aft':48,64 'approval':63 'area...
#
# [557 rows x 16 columns]

# %%
# %%sql
# COPY
# (SELECT zerver_usermessage.id::UBIGINT as id,
#         zerver_usermessage.user_profile::UBIGINT as user_profile,
#         zerver_usermessage.message::UBIGINT as message,
#         zerver_usermessage.flags_mask::BOOLEAN as flags_mask
# FROM './zerver_usermessage.json'
# ) TO './zerver_usermessage.parquet' (FORMAT PARQUET);
# Out:
#    Count
# 0  53386

# %%
# %%sql
# COPY (
# SELECT  zerver_message.id::UBIGINT as id,
#         zerver_message.sender::UBIGINT as sender,
#         zerver_message.recipient::BIGINT as recipient,
#         zerver_message.realm::UBIGINT as realm,
#         zerver_message.subject::VARCHAR as subject,
#         zerver_message.content::VARCHAR as content,
#         zerver_message.rendered_content::VARCHAR as rendered_content,
#         zerver_message.rendered_content_version::UBIGINT as rendered_content_version,
#         zerver_message.date_sent::VARCHAR as date_sent,
#         zerver_message.sending_client::BIGINT as sending_client,
#         zerver_message.last_edit_time::VARCHAR as last_edit_time,
#         zerver_message.edit_history::VARCHAR as edit_history,
#         zerver_message.has_attachment::BOOLEAN as has_attachment,
#         zerver_message.has_image::BOOLEAN as has_image,
#         zerver_message.has_link::BOOLEAN as has_link,
#         zerver_message.search_tsvector::VARCHAR as search_tsvector
# FROM './zerver_message.json'
# )
# TO './zerver_message.parquet' (FORMAT PARQUET);
# Out:
#    Count
# 0    557

# %% [markdown]
# ## Visualization of the Zulip chat data

# %%
import vegafusion as vf
import polars as pl
import altair as alt
import altair as alt
alt.data_transformers.disable_max_rows()
alt.renderers.enable('html')

# Configure DuckDB connection
vf.runtime.set_connection("duckdb")

# Enable Mime Renderer
vf.enable(row_limit=100000000)
# Out:
# vegafusion.enable(mimetype='html', row_limit=100000000, embed_options=None)

# %%
# Load the chat data into a Polars datafram
zulip_chat = pl.read_parquet("data/datathinking.zulipchat.com/processed/zerver_message.parquet")

# %%
# Or, load it from the Amazon S3 public bucket for data thinking
zulip_chat = pl.read_parquet("https://public.datathinking.org/datathinking.zulipchat.com%2Fzerver_message.parquet")

# %%
zulip_chat
# Out:
# shape: (557, 16)
# ┌───────────┬────────┬───────────┬───────┬───┬───────────────┬───────────┬──────────┬──────────────┐
# │ id        ┆ sender ┆ recipient ┆ realm ┆ … ┆ has_attachmen ┆ has_image ┆ has_link ┆ search_tsvec │
# │ ---       ┆ ---    ┆ ---       ┆ ---   ┆   ┆ t             ┆ ---       ┆ ---      ┆ tor          │
# │ u64       ┆ u64    ┆ i64       ┆ u64   ┆   ┆ ---           ┆ bool      ┆ bool     ┆ ---          │
# │           ┆        ┆           ┆       ┆   ┆ bool          ┆           ┆          ┆ str          │
# ╞═══════════╪════════╪═══════════╪═══════╪═══╪═══════════════╪═══════════╪══════════╪══════════════╡
# │ 299488052 ┆ 100007 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ true     ┆ 'demonstrate │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ ':2,14 'demo │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ nstratio…    │
# │ 299488053 ┆ 100007 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ true     ┆ 'conversatio │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ n':10 'demon │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ strate':…    │
# │ 299488054 ┆ 100007 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ true      ┆ true     ┆ 'general':9  │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'message':6, │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 28 'new'…    │
# │ 327255223 ┆ 544719 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ false    ┆ 'agency':32  │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'artificial' │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ :59 'beh…    │
# │ …         ┆ …      ┆ …         ┆ …     ┆ … ┆ …             ┆ …         ┆ …        ┆ …            │
# │ 368051747 ┆ 587794 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ true     ┆ '/ikr503/blo │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ g.datathinki │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ ng.org/b…    │
# │ 368053528 ┆ 590536 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ true     ┆ '/onefact/da │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ tathinking.o │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ rg/issue…    │
# │ 368055562 ┆ 622748 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ false    ┆ '2':106      │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ '3':37 'assu │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ mption':118  │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ …            │
# │ 368056816 ┆ 622751 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ false    ┆ '-1':84      │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ '1':83       │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'aft':48,64  │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'appr…       │
# └───────────┴────────┴───────────┴───────┴───┴───────────────┴───────────┴──────────┴──────────────┘

# %% [markdown]
# ## How can we check this is the actual data?
# * look at Zulip and compare?
# the most recent message:
# > My experience report: Engaging with these new tools and code was very intimidating, especially trying to tackle the instructions on my own. I expected this feeling as this area is unfamiliar to me. The first obstacle was trying to get the student development pack verified. After finally figuring out the VPN issue, I still did not receive a confirmation of approval. After multiple attempts and a lot of feelings of overwhelm and stress, I decided to reach out and attend 1-1 office hours with Jaan. Through this office hour and the guidance of Jaan, it was easier to be more patient with myself, break down instructions given, navigate new tools, and troubleshoot when things didn't run smoothly. Having the guidance of the instructor the assignment seems a lot less intimidating and easier to tackle. Similarly to what Jalynn said, I did not know that my laptop had something called a terminal. The hardest part for me was understanding specific vocabulary and navigating new tools ie. knowing what buttons to click, where to find files etc.
#
#
# can we find this message in the data in python?

# %%
zulip_chat['content'][-1]
# Out:
# "My experience report: Engaging with these new tools and code was very intimidating, especially trying to tackle the instructions on my own. I expected this feeling as this area is unfamiliar to me. The first obstacle was trying to get the student development pack verified. After finally figuring out the VPN issue, I still did not receive a confirmation of approval. After multiple attempts and a lot of feelings of overwhelm and stress, I decided to reach out and attend 1-1 office hours with Jaan. Through this office hour and the guidance of Jaan, it was easier to be more patient with myself, break down instructions given, navigate new tools, and troubleshoot when things didn't run smoothly. Having the guidance of the instructor the assignment seems a lot less intimidating and easier to tackle. Similarly to what Jalynn said, I did not know that my laptop had something called a terminal. The hardest part for me was understanding specific vocabulary and navigating new tools ie. knowing what buttons to click, where to find files etc."

# %%
zulip_chat['content'][-1] == "My experience report: Engaging with these new tools and code was very intimidating, especially trying to tackle the instructions on my own. I expected this feeling as this area is unfamiliar to me. The first obstacle was trying to get the student development pack verified. After finally figuring out the VPN issue, I still did not receive a confirmation of approval. After multiple attempts and a lot of feelings of overwhelm and stress, I decided to reach out and attend 1-1 office hours with Jaan. Through this office hour and the guidance of Jaan, it was easier to be more patient with myself, break down instructions given, navigate new tools, and troubleshoot when things didn't run smoothly. Having the guidance of the instructor the assignment seems a lot less intimidating and easier to tackle. Similarly to what Jalynn said, I did not know that my laptop had something called a terminal. The hardest part for me was understanding specific vocabulary and navigating new tools ie. knowing what buttons to click, where to find files etc."
# Out:
# True

# %%
zulip_chat["content"][0]
# Out:
# 'This is a message on stream #**general** with the topic `topic demonstration`.'

# %%
zulip_chat["subject"] == "experience reports"
# Out:
# shape: (557,)
# Series: 'subject' [bool]
# [
# 	false
# 	false
# 	false
# 	false
# 	false
# 	false
# 	false
# 	false
# 	false
# 	false
# 	false
# 	false
# 	…
# 	false
# 	false
# 	false
# 	false
# 	false
# 	false
# 	true
# 	false
# 	false
# 	false
# 	false
# 	true
# 	true
# ]

# %%
zulip_chat.filter(pl.col("subject") == "experience reports")
# Out:
# shape: (24, 16)
# ┌───────────┬────────┬───────────┬───────┬───┬───────────────┬───────────┬──────────┬──────────────┐
# │ id        ┆ sender ┆ recipient ┆ realm ┆ … ┆ has_attachmen ┆ has_image ┆ has_link ┆ search_tsvec │
# │ ---       ┆ ---    ┆ ---       ┆ ---   ┆   ┆ t             ┆ ---       ┆ ---      ┆ tor          │
# │ u64       ┆ u64    ┆ i64       ┆ u64   ┆   ┆ ---           ┆ bool      ┆ bool     ┆ ---          │
# │           ┆        ┆           ┆       ┆   ┆ bool          ┆           ┆          ┆ str          │
# ╞═══════════╪════════╪═══════════╪═══════╪═══╪═══════════════╪═══════════╪══════════╪══════════════╡
# │ 364697501 ┆ 544719 ┆ 924073    ┆ 47304 ┆ … ┆ true          ┆ true      ┆ true     ┆ '/api/views/ │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ erm2-nwe9/ro │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ ws.csv?a…    │
# │ 364697542 ┆ 544719 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ true     ┆ '/github/one │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ fact/datathi │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ nking.or…    │
# │ 365383919 ┆ 622681 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ false    ┆ '-2022':244  │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ '2021':243   │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'abt':456…   │
# │ 365386362 ┆ 622681 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ false    ┆ '3':17       │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'body':18    │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'chat':9     │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'chat-…      │
# │ …         ┆ …      ┆ …         ┆ …     ┆ … ┆ …             ┆ …         ┆ …        ┆ …            │
# │ 367745332 ┆ 622765 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ false    ┆ '10':160     │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'along':61   │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'also':59,10 │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ …            │
# │ 368017965 ┆ 623113 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ true     ┆ 'able':12,32 │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 0 'activate' │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ :14,212 …    │
# │ 368055562 ┆ 622748 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ false    ┆ '2':106      │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ '3':37 'assu │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ mption':118  │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ …            │
# │ 368056816 ┆ 622751 ┆ 924073    ┆ 47304 ┆ … ┆ false         ┆ false     ┆ false    ┆ '-1':84      │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ '1':83       │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'aft':48,64  │
# │           ┆        ┆           ┆       ┆   ┆               ┆           ┆          ┆ 'appr…       │
# └───────────┴────────┴───────────┴───────┴───┴───────────────┴───────────┴──────────┴──────────────┘

# %%
zulip_chat.filter(pl.col("subject") == "experience reports")["content"]
# Out:
# shape: (24,)
# Series: 'content' [str]
# [
# 	"i'm confused b…
# 	"these seem to …
# 	"Here's my expe…
# 	"When i plugged…
# 	"Wow I really a…
# 	"Also just dm’e…
# 	"Hello everyone…
# 	"Hi all! My exp…
# 	"Hello everyone…
# 	"@_**Sakariya M…
# 	"@_**Jane Castl…
# 	"I actually alr…
# 	"Here is my exp…
# 	"I was tasked w…
# 	"thank you @**D…
# 	"Here’s my expe…
# 	"I got overwhel…
# 	"amazing work @…
# 	"I tried the ho…
# 	"This my ChatGP…
# 	"My experience …
# 	"@_**Moses Njug…
# 	"My experience …
# 	"My experience …
# ]

# %%
list_of_all_experience_reports = zulip_chat.filter(pl.col("subject") == "experience reports")["content"].to_list()

# %%
list_of_all_experience_reports
# Out:
# ['i\'m confused because the instructions i googled were incorrect, and it\'s frustrating! (https://code.visualstudio.com/docs/sourcecontrol/github) and i had to trust a folder but i\'m not sure if that\'s dangerous.\n\ni got so many errors trying to follow the instructions/algorithm: \n\n```\n------------------------------------------\nFileNotFoundError                         Traceback (most recent call last)\nCell In[1], line 2\n      1 import urllib.request\n----> 2 urllib.request.urlretrieve("https://data.cityofnewyork.us/api/views/erm2-nwe9/rows.csv?accessType=DOWNLOAD", "./data/cityofnewyork.us/311-Service-Requests-from-2010-to-Present.csv")\n\nFile /opt/homebrew/anaconda3/envs/datathinking.org-test/lib/python3.11/urllib/request.py:251, in urlretrieve(url, filename, reporthook, data)\n    249 # Handle temporary file setup.\n    250 if filename:\n--> 251     tfp = open(filename, \'wb\')\n    252 else:\n    253     tfp = tempfile.NamedTemporaryFile(delete=False)\n\nFileNotFoundError: [Errno 2] No such file or directory: \'./data/cityofnewyork.us/311-Service-Requests-from-2010-to-Present.csv\'\n```\n\n```\nIOException: IO Error: No files found that match the pattern "./data/cityofnewyork.us/311-Service-Requests-from-2010-to-Present.csv"\n```\n\n```\nIOException: IO Error: No files found that match the pattern "./data/cityofnewyork.us/311-Service-Requests-from-2010-to-Present.csv"\n```\n\n```\nFileNotFoundError: No such file or directory: ./data/cityofnewyork.us/311-Service-Requests-from-2010-to-Present.parquet\n```\n\nat least i got this visualization, so i seem to have done at least one thing correct and i\'m still worriied i\'m the problem: \n\n[image.png](/user_uploads/47304/aT01Vo8nEaaoNWqviM0mUl9w/image.png)\n[image.png](/user_uploads/47304/NFKathKTcZ4a7oQP1kwKx6mq/image.png)',
#  "these seem to match what was intended at https://nbviewer.org/github/onefact/datathinking.org-codespace/blob/main/notebooks/princeton-university/week-1-visualizing-33-million-phone-calls-in-new-york-city.ipynb so i guess it's okay? but instructinos were very unclear!",
#  'Here\'s my experience report...it\'s going to be more like a RANT because that\'s kinda what I need in this moment. I\'m feeling many parts angry, antsy, anxious, and stressed right now. I just read that imposter syndrome article in the new yorker and it pushed many chords in me. I personally could\'ve done without the ending of the article where the author universalizes "imposter phenomenom" to life experience in a very white-liberal move. But overall, great read- especially its meditation on how for people of color, the term "imposter syndrome" pathologizes individual experience and obscures the systemic racism that often manifests feelings of fraudulence and self-doubt.\n\nWhat really tightened a knot in my chest was the anecdote about Adaira Landry, a first-gen African American woman, whose feelings of self-doubt were *dismissed* as imposter syndrome. Looking back, Landry sees that what she needed was recognition that her feelings were real, and coerced into existence by systemic racism that shaped her existence on the med school campus.\n\nThis is the recognition that Landry provides her students now, and she can see the relief from her students when hearing these words. THIS is the dynamic that has me a bit stressed, because it brings me back to my time working for the McGraw center at Princeton, a tutoring and learning resource for students. I was a learning consultant in 2021-2022, and a similar method I would use would be to tell students that Princeton\'s academic structure was built against them. **And I\'d get so so much push back from my peers during trainings when I would introduce this method.** Because of the support I didn\'t get in my training and from the McGraw center, I even felt scared at times to tell Black/POC students that their "imposter" feelings and their struggles in the classroom weren\'t on them but rather because of the hegemony of the classroom and academic structure. It felt like a truth only to be spoken behind close doors, which makes sense... because McGraw is Princeton\'s creation, partly functioning to train students to tutor and help each other so the University doesn\'t have to reduce course loads, or lengthen academic terms, or alleviate academic/graduation requirements.\n\nI even felt so compelled as to write a note to my former McGraw boss on these thoughts and share/summarize the article for them. I feel so freaking jittery and anxious right now because this is the feeling I get when I stand-up for myself or speak up blejhajsdbfjksadbfjksdafdjsk. refleciton complete.\n\ntl;dr liked the imposter article. stressed because it implicates how imposter syndrome is talked abt at Princeton but also how it\'s perpetuated by student resource centers like McGraw. stressed also because I complained to my former McGRaw boss (Nic Voge) abt it.',
#  'When i plugged this into Chat-GPT, it literally turned this^ into a 3 body paragraph essay',
#  'Wow I really appreciate your experience @**Daniel Wey** 🙏. I’m proud of you for (1) going above and beyond your role at McGraw to help Black/POC students understand the broader hegemony of academia and classrooms. And (2) being able to eloquently connect the dots between this slew of difficult personal experiences getting shut down while trying to help… \n\nStudent resource centers are in an interesting bind. If they implicate themselves (and acquiesce to your implication of the hegemony and structure having adverse consequences for some students vs others), then legal liability can be created. See for example the many cases of students allegedly feeling forced to withdraw after mental health crises were learned about by the school: https://www.chronicle.com/article/sent-away\n\nIn this case, I see a similarity to “AI safety” discussions held at big tech companies being an attractive way to deflect discussion of greater harms occurring immediately rather than in the far-off future. Perhaps “impostor syndrome” and its attendant word salad can serve a similar purpose for student resource centers who choose to avoid discussion of power structures and hegemony as you rightfully suggest they do. Well done.⚡️',
#  'Also just dm’ed you in case you decide to share a note with your old boss. Happy to help! The jitters come for me too when speaking out on behalf of myself or others, and I often need a lottt of support in those moments — so try to pay it forward when I can!',
#  'Hello everyone, here’s my experience report:\nHave you ever been given a task and in your head you are extremely confident you can perform said task furthermore perform it quickly. Then all of a sudden that task turns out to be harder than expected. You keep performing the instructions and keep getting the same answer of an error. Because of your confidence you don’t think “hey maybe the instructions are wrong” and due to this you keep making the same mistake. \nJaan’s lecture was amazing and the best part for me was when he went through the instructions and basically said that they were bad. Going on then to show us to think outside the box. This evidently is what helped me the most through the installation process. The terminal was stating that I did not have Pip and conda downloaded. And because of that I could not download all the other extensions and data. I kept repeating the instructions believing something was wrong with my computer until I thought maybe the instructions itself were wrong. That’s when I went directly and downloaded an andaconda Mac OS intel installer. Performed the tasks then CREATED a path for conda. Then I downloaded python 3.11 and Pip on my Mac. These steps were not on the list. After that everything went smoothly. I’m on the data visualization part and I believe that I will still run into problems however I also believe thinking outside the box will help me again.',
#  "Hi all! My experience report: as I was working through these homework tasks, I was struck by the fact that the various ideas brought up in the readings, exercises, and coding problems all come from various disciplines - from etymology to psychology to programmatic computer science. I found myself aiming to connect the dots between these moving parts as I progressed through the homework. I'm interested to continue developing this approach to data thinking - far more unique and transdisciplinary than any previous CS courses I have taken, which tend to privilege mathematical/scientific knowledge above other forms!",
#  "Hello everyone, my experience report: I have had trouble setting up virtual environments in the past, so I was worried about running into errors setting up this environment. I ran into issues with my virtual environment having all of the installed packages, but the Jupyter notebook still returning errors that different modules could not be found. I eventually realized that because I have multiple versions of Python on my laptop, the packages I installed for my virtual environment needed to be reinstalled on a different path for a different Python interpreter. This resolved most of my issues, and it was satisfying to better understand how the virtual environment works. I still have one module not found error, but I’ll attend office hours to help resolve that problem, and I’m looking forward to getting into the data justice work once our set up is complete. I also thought the other tasks of putting my phone on do not disturb was really helpful for my focus, but tracking every minute of my day on Google calendar was less effective because I would feel bad if I got off-schedule and felt like I didn't have as much freedom in my day.",
#  "@_**Sakariya Mohamud|623389** [said](https://datathinking.zulipchat.com/#narrow/stream/345278-general/topic/experience.20reports/near/365446290):\n```quote\nHello everyone, here’s my experience report:\n```\nyou're doing amazing @**Sakariya Mohamud** so proud of you!! you are nailing it :raised_hands:  \n\nindividually each one of these things can be very difficult so awesome work on getting help (i assume from google, chatgpt, claude and elsewhere?) as you got stuck on each one of these things. even getting 'stuck' is a misnomer if the instructions are bad ;)",
#  '@_**Jane Castleman|622689** [said](https://datathinking.zulipchat.com/#narrow/stream/345278-general/topic/experience.20reports/near/365547443):\n```quote\nHello everyone, my experience report:\n```\nnice work @**Jane Castleman** !! yes let\'s get that last module error fixed :) \n\n\n> I also thought the other tasks of putting my phone on do not disturb was really helpful for my focus, but tracking every minute of my day on Google calendar was less effective because I would feel bad if I got off-schedule and felt like I didn\'t have as much freedom in my day.\n\nthis is good to know!! and i\'m curious what you mean by "off-schedule". do you not adjust the tasks to reflect what you actually did? i change my calendar at the end of the day (on many / most days) to reflect what i actually did!',
#  "I actually already use google calendar to schedule my day almost minute to minute because it reduces my anxiety about making sure I have enough time to get everything done while also showing me where more flexibility is in my schedule. This assignment really made me think about why I do it, since I almost never do everything exactly as planned. Honestly more times than not I just use it as a general guide of how my day should be structured. I realized that I like being able to move things around when my plans change while knowing I still will have time to get everything done. Additionally, I change my calendar to match what I actually did that day which is super helpful for looking back to see what events I had on what days. It makes me happy to look at both the things that I actually did and my plans for the future.\n\nchatgbt edit: I already use Google Calendar to schedule my day, often down to the minute, which helps alleviate my anxiety about managing my time effectively. It serves as a general guide for structuring my day, although I rarely adhere to it strictly. Instead, I appreciate the flexibility it offers when my plans change. I find it beneficial to rearrange my schedule while ensuring I still have ample time to accomplish everything. Moreover, I update my calendar to reflect the events I actually attended, which proves valuable for reviewing past activities. Reflecting on both completed tasks and future plans brings me joy and satisfaction.\n\nI really like the way this sounds so much more because it makes the connections between sentences to make it flow better as one complete paragraph. However, it doesn't mention the connection to the assignment which I feel was crucial to make it relevant.",
#  'Here is my experience report: I found all of the required readings to be really compelling but I really was interested in the you\'re probably using the wrong dictionary article.  Often I know words but then I think what is the exact definition and I google it.  It can be the most mundane word but I like to do it.  This article challenged me because it challenged the precise nature of the dictionary we use today.  As they put it they "boil it down to her essence".  What really stuck out was that they said to use anything but the dictionary that was more descriptive was "to keep yourself forever at the arms length from the actual language."  It made me think about how we use science and reason to try to explain our world and how as we advance as a society we feel more need to control as if that will bring us closer to understand everything.  I think this may be why we have forgone these more in depth and almost uncertain definitions in the 1913 Webster\'s dictionary and replaced it with our succinct definitions we have today.  I think it is cool there exists this dictionary and as the article said it reminds us that words existed before the definition which I think is the best way we should think of words.\n\nCoding: I always struggle to start the coding section.  I always feel like I am inherently going to be bad at it and also I think anytime you are used to excelling it is difficult to start learning something new.  It requires you to be a novice and out in time.  When you don\'t immediately see results you can feel discouraged and not want to continue and avoid it.  I eventually tried to build the environment and was confused by the article and then the second sequence in Visual Code Studio.  I was frustrated with the environment and not knowing how to do it.  But then I remembered I could use ChatGPT.  In asking ChatGPT I was able to get further into the environment building. But then I also got stuck at writing the line into file.  When I asked ChatGPT it said that I had to use Visual Code but I was not sure if that was right so then I got frustrated again.  \n\nIt is cool however that there exists this thing called Terminal that has always existed on my computer and I never knew about it or that I could use it.  It is crazy how we can think we know how to use our computer when really we only use a portion of it as we know how to do.',
#  "I was tasked with installing the datathinking environment. Having realized step one was already completed, I was hopeful for smooth sailing. Unfortunately, it didn't turn out so and as I got to the next step I found myself stuck in the terminal for an extensive amount of time trying to paste in the commands, but being met with the same errors. I took to an internet stack forum but it was to no avail. Feeling frustrated and hopeless, I got in touch with a peer and we both struggled with the same issue.  Today there's an office hours and I hope to solve the problem there",
#  "thank you @**Danyal Jawed** ! yes let's go through this in office hours and take a look at some of those errors -- nice work documenting the frustration here. it took me many thousand hours to get less hopeless/frustrated at this process so it takes time and support -- support that we aim to give you here!",
#  'Here’s my experience attempting to visualize the call data after building the environment and opening the notebook in Visual Studio Code: \nI ran into a lot of roadblocks throughout the process, as downloading the data, reading the CSV file, and importing the necessary packages all resulted in confusing errors.  I asked ChatGPT for help with all these steps. However, a lot of the solutions it offered were inapplicable, so this process was more frustrating than I anticipated. I eventually turned to Google for help instead. For certain portions, this proved to be more helpful. For others, I found that solutions on sites like StackOverflow either didn’t relate closely enough to my issue or were confusing to implement. \nI was relieved to eventually find solutions to all my early issues. I made it to the  “Visualizing the data” portion of the notebook and thought things would go relatively smoothly here, but I immediately ran into more problems. Importing Vegafusion resulted in a ModuleNotFoundError that I couldn’t figure out how to solve, regardless of what I searched online or asked ChatGPT. This reflects one of my major struggles with working in Visual Studio Code. Ensuring necessary packages are downloaded into the right place feels pretty tedious and confusing. There were a lot of times where I would feel confident I was downloading something into the correct location only to get a ModuleNotFoundError when I tried to import it later on.',
#  "I got overwhelmed after not being able to activate GitHub Copilot. I also couldn't find where to select kernels. I spent a lot of time trying to navigate the different parts of the Visual studio window but it turns out the option to select kernels was at the top right corner. I went to office hours and I think this was super helpful. I ave always been afraid of using Visual Studio code. I had a class last semester where I chose to code on the terminal in the emacs editor rather than download VS code and set it up. That being said, I am happy I managed, through Jaan's amazing help, to navigate the instructions and see the visualizations.",
#  'amazing work @**Moses Njuguna** !!!! so proud of you!!!!!!',
#  'I tried the homework in my own way (started with an end in my mind, but not following the steps), of course most of the things did not work. Therefore, I felt frustrated but after somedays I released that there are some steps I had jumped, which made my work to be incomplete. I, therefore, started over and I was able to do the visualization for like 30 seconds. The reason behind this, is that I clicked "Run" on the Cells and my Kernel \'datathinking.org (Python 3.11.0)\' died. I guess it might be a problem of the processor or it is just a new way of learning.  Check the message I got after my Kernel died! :point_down:\n[well-well-well.jpg](/user_uploads/47304/jOmxn1ZuCYdTg8oAXtuKPQHi/well-well-well.jpg)',
#  'This my ChatGPT version of the experience report. It looks good, but I really did not like it because it does not have the heart and the soul that I always try to give my messages. :joy: \n\nI approached the homework in my own unique manner, deviating from the prescribed steps and instead starting with a predetermined outcome in mind. However, it became evident that my approach yielded unsatisfactory results. Consequently, I experienced a sense of frustration. Upon reflection, I realized that I had skipped certain crucial steps, which ultimately led to an incomplete work. Recognizing this, I decided to start anew, allowing me to successfully visualize the desired outcome for approximately 30 seconds. The reason behind this achievement can be attributed to my action of clicking "Run" on the Cells, unfortunately resulting in the untimely termination of my Kernel, specifically \'datathinking.org (Python 3.11.0)\'. It is plausible that this issue stems from a processor-related problem or simply represents a novel learning experience. I invite you to review the message I received subsequent to the unexpected termination of my Kernel.',
#  'My experience report is that when trying to start up python and the conda environment in visual studio code felt like being a baby locked in a hot car. Time was passing, nothing was getting solved, and I had no idea what was going on. I felt better in bootcamp meetings finding out that others were also lost along the way, and eventually I figured things out. I found taking breaks helped, and sometimes it seemed like code I tried before that failed just needed to be run again. It was very cool to see things work out and know support is available, but also gratifying to solve even small issues. It is uncomfortable to work on things without any idea how long they will take. I know, for example, roughly how long it will take me to read data feminism because I read at a consistent speed. With the bootcamp tasks, things I thought would take 10 minutes took hours, and things I thought would take forever ended up not being so bad. I think getting comfortable with that unpredictability helps mitigate frustration. I have enjoyed playing with chatGPT and even being encouraged to do so.',
#  '@_**Moses Njuguna|623113** [said](https://datathinking.zulipchat.com/#narrow/stream/345278-general/topic/experience.20reports/near/366903841):\n```quote\nI got overwhelmed after not being able to activate GitHub Copilot. I also couldn\'t find where to select kernels. I spent a lot of time trying to navigate the different parts of the Visual studio window but it turns out the option to select kernels was at the top right corner. I went to office hours and I think this was super helpful. I ave always been afraid of using Visual Studio code. I had a class last semester where I chose to code on the terminal in the emacs editor rather than download VS code and set it up. That being said, I am happy I managed, through Jaan\'s amazing help, to navigate the instructions and see the visualizations.\n```\nchatgpt edit: (Chose not to post this initially because I didn\'t really like how it read. I felt like it did not sufficiently relay the emotional relief that came with understanding how to navigate VS code. I often have to issue instructions like " write this in a more witty way/ write this like a NYT journalist would" to chatgpt to find the tone that most closely reflects the tone I would use while writing something similar). \nI became overwhelmed when I couldn\'t activate GitHub Copilot, and I also struggled to locate the option for selecting kernels. I spent a considerable amount of time trying to navigate through the various sections of the Visual Studio Code window, only to realize that the kernel selection was located at the top right corner. However, attending office hours proved to be immensely valuable as I received valuable assistance. I\'ve always had reservations about using Visual Studio Code, as in a previous semester, I opted to code in the Emacs editor via the terminal instead of downloading and setting up VS Code. Nevertheless, I\'m delighted that with Jaan\'s incredible guidance, I was able to navigate the instructions and visualize my progress.',
#  'My experience report: I had trouble setting up my virtual environment. I’ve had issues with VSCode in the past, especially with regards to installing libraries and packages. One problem is that I have 3 different versions of VSCode on my computer with different libraries installed on each one. While trying to visualize the data, I ran into problems as chatGPT’s suggestions did not work and had to spend time trying to debug instead. Knowing that other people were struggling with setup as well and having someone who I could share error messages with helped. Going over our work from the last 2 weeks, I found it interesting to think about how my own assumptions and beliefs drive how I interact with technology.',
#  "My experience report: Engaging with these new tools and code was very intimidating, especially trying to tackle the instructions on my own. I expected this feeling as this area is unfamiliar to me. The first obstacle was trying to get the student development pack verified. After finally figuring out the VPN issue, I still did not receive a confirmation of approval. After multiple attempts and a lot of feelings of overwhelm and stress, I decided to reach out and attend 1-1 office hours with Jaan. Through this office hour and the guidance of Jaan, it was easier to be more patient with myself, break down instructions given, navigate new tools, and troubleshoot when things didn't run smoothly. Having the guidance of the instructor the assignment seems a lot less intimidating and easier to tackle. Similarly to what Jalynn said, I did not know that my laptop had something called a terminal. The hardest part for me was understanding specific vocabulary and navigating new tools ie. knowing what buttons to click, where to find files etc."]

# %%
zulip_chat.filter(pl.col("subject") == "experience reports")["content"].apply
# Out:
# <bound method Series.apply of shape: (24,)
# Series: 'content' [str]
# [
# 	"i'm confused b…
# 	"these seem to …
# 	"Here's my expe…
# 	"When i plugged…
# 	"Wow I really a…
# 	"Also just dm’e…
# 	"Hello everyone…
# 	"Hi all! My exp…
# 	"Hello everyone…
# 	"@_**Sakariya M…
# 	"@_**Jane Castl…
# 	"I actually alr…
# 	"Here is my exp…
# 	"I was tasked w…
# 	"thank you @**D…
# 	"Here’s my expe…
# 	"I got overwhel…
# 	"amazing work @…
# 	"I tried the ho…
# 	"This my ChatGP…
# 	"My experience …
# 	"@_**Moses Njug…
# 	"My experience …
# 	"My experience …
# ]>

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/me/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Import stop words list
from nltk.corpus import stopwords 
from collections import Counter

# Remove stop words and tokenize 
message_list = zulip_chat.filter(pl.col("subject") == "experience reports")["content"].apply(lambda msg: [word for word in msg.lower().split() if word not in stopwords.words('english')])

# Flatten list of lists into single list of words 
words = [word for msg in message_list for word in msg]

# Count frequencies 
counts = Counter(words)

# Sort counts and take top 10 
top_words = counts.most_common(10) 

# Create bar chart 
chart = alt.Chart(top_words).mark_bar().encode(
    x='count', 
    y=alt.Y('word', sort='-x')
)

# %%
top_words
# Out:
# [('like', 18),
#  ('experience', 15),
#  ('think', 15),
#  ('also', 14),
#  ('instructions', 13),
#  ('use', 13),
#  ('got', 12),
#  ('really', 12),
#  ('time', 12),
#  ('trying', 11)]

# %%
# altair chart for plotting top words

# %%
counts.most_common(100)
# Out:
# [('like', 18),
#  ('experience', 15),
#  ('think', 15),
#  ('also', 14),
#  ('instructions', 13),
#  ('use', 13),
#  ('got', 12),
#  ('really', 12),
#  ('time', 12),
#  ('trying', 11),
#  ('```', 11),
#  ('things', 11),
#  ('visual', 11),
#  ('code', 11),
#  ('would', 10),
#  ('get', 10),
#  ('work', 10),
#  ('found', 9),
#  ('felt', 9),
#  ('studio', 9),
#  ("i'm", 8),
#  ('one', 8),
#  ('students', 8),
#  ('see', 8),
#  ('feel', 8),
#  ('report:', 8),
#  ('environment', 8),
#  ('office', 8),
#  ('hours', 8),
#  ('navigate', 8),
#  ('still', 7),
#  ('right', 7),
#  ('help', 7),
#  ('able', 7),
#  ('getting', 7),
#  ('different', 7),
#  ('calendar', 7),
#  ('always', 7),
#  ('chatgpt', 7),
#  ('lot', 7),
#  ('many', 6),
#  ('going', 6),
#  ('article', 6),
#  ('mcgraw', 6),
#  ('it.', 6),
#  ('terminal', 6),
#  ('thought', 6),
#  ('day', 6),
#  ('google', 6),
#  ('actually', 6),
#  ('find', 6),
#  ('feeling', 5),
#  ('new', 5),
#  ('often', 5),
#  ('feelings', 5),
#  ('support', 5),
#  ('even', 5),
#  ('vs', 5),
#  ('way', 5),
#  ('said', 5),
#  ('amazing', 5),
#  ('went', 5),
#  ('could', 5),
#  ('something', 5),
#  ('computer', 5),
#  ('tasks', 5),
#  ('data', 5),
#  ('virtual', 5),
#  ('eventually', 5),
#  ('dictionary', 5),
#  ('know', 5),
#  ('code.', 5),
#  ('errors', 4),
#  ('file', 4),
#  ('match', 4),
#  ('parts', 4),
#  ('imposter', 4),
#  ('learning', 4),
#  ('resource', 4),
#  ('much', 4),
#  ('rather', 4),
#  ('hegemony', 4),
#  ('student', 4),
#  ('happy', 4),
#  ('hello', 4),
#  ('everyone,', 4),
#  ('keep', 4),
#  ('python', 4),
#  ('everything', 4),
#  ('setting', 4),
#  ('ran', 4),
#  ('realized', 4),
#  ('minute', 4),
#  ('less', 4),
#  ('bad', 4),
#  ('stuck', 4),
#  ('last', 4),
#  ('made', 4),
#  ('plans', 4),
#  ('knowing', 4)]

# %%
import pandas as pd
# create a dataframe from your data
df = pd.DataFrame(counts.most_common(100), columns=['word', 'frequency'])

# %%
df
# Out:
#             word  frequency
# 0           like         18
# 1     experience         15
# 2          think         15
# 3           also         14
# 4   instructions         13
# ..           ...        ...
# 95         stuck          4
# 96          last          4
# 97          made          4
# 98         plans          4
# 99       knowing          4
#
# [100 rows x 2 columns]

# %%
# create a bar chart
chart = alt.Chart(df).mark_bar().encode(
    y=alt.Y('word:N', title='Words', sort='-x'),
    x=alt.X('frequency:Q', title='Frequency'),
)

# %%
chart
# Out:
# alt.Chart(...)

# %%
# count the number of words in each message
zulip_chat.filter(pl.col("subject") == "experience reports")["content"].apply(lambda msg: len(msg.split()))
# Out:
# shape: (24,)
# Series: 'content' [i64]
# [
# 	155
# 	19
# 	457
# 	16
# 	187
# 	55
# 	248
# 	97
# 	198
# 	71
# 	125
# 	304
# 	450
# 	106
# 	57
# 	238
# 	120
# 	9
# 	118
# 	179
# 	197
# 	322
# 	122
# 	175
# ]
